# %%
import numpy as np
import scipy as scp
import cv2
import os
import pandas as pd

# %%
labels = pd.DataFrame([
                        [1,"EOSINOPHIL",],
                        [2,"LYMPHOCYTE",],
                        [3,"MONOCYTE",],
                        [4,"NEUTROPHIL",],
                    ],columns=["index", "cell type"])

# %%
labels
# Out:
#    index   cell type
# 0      1  EOSINOPHIL
# 1      2  LYMPHOCYTE
# 2      3    MONOCYTE
# 3      4  NEUTROPHIL

# %%
path = "..\\Datasets\\archive\\dataset-master\\dataset-master\\JPEGImages\\"

images = []
index = []

for filename, i in zip(os.listdir(path=path), range(401)):
    img = cv2.imread(os.path.join(path, filename))
    if img is not None:
        index.append(i)
        images.append(img)

# index = np.array(index)
# images = np.array(images)
# label = np.array([""] * len(index))

print("Images loaded.")
# Out:
# Images loaded.

# %%
loaded_images = pd.DataFrame([index, images, label])
loaded_images
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 loaded_images = pd.DataFrame([index, images, label])
# ----> 2 loaded_images
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\displayhook.py:262, in DisplayHook.__call__(self, result)
#     260 self.start_displayhook()
#     261 self.write_output_prompt()
# --> 262 format_dict, md_dict = self.compute_format_data(result)
#     263 self.update_user_ns(result)
#     264 self.fill_exec_result(result)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\displayhook.py:151, in DisplayHook.compute_format_data(self, result)
#     121 def compute_format_data(self, result):
#     122     """Compute format data of the object to be displayed.
#     123
#     124     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     149
# ...
